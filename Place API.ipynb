# %% [markdown]
# Google place API: <br/>
# https://developers.google.com/places/web-service/overview

# %% [markdown]
# There are two ways to get data from Google API, <br/>(1) googlemaps module: https://github.com/googlemaps<br/>(2) traditional request & get

# %% [markdown]
# #### Traditional request & get method

# %%
import requests
from urllib.parse import urlencode
import time

# %% [markdown]
# url pattern: 'https://maps.googleapis.com/maps/api/place/nearbysearch/output?parameters'
# <br/>url example: 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=mongolian%20grill&inputtype=textquery&fields=photos,formatted_address,name,opening_hours,rating&locationbias=circle:2000@47.6918452,-122.2226413&key=YOUR_API_KEY'

# %%
print(url_base)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json

# %%
para_encoded = urlencode(parameters)

# %%
url = f"{url_base}?{r.json()['next_page_token']}"
url
# Out:
# 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?ATtYBwJdYtXib0lpeJZpzosqe6LhVQLQXWcv_CxzY9ABzQphCV5u8WDdMwU2JISjWMXoZJCrIEGY53lhXWo6yKQdSaRuc9rnfkeCucG3jlD_56NcVS2_4wzSWa19l_6j33spYQdBONZY954EIajTLaLu_2JBbT96Y4zTPRMLVHvJhACtmJzMrQ-l6n6l6f-rbezjOVgpciS56LmGVvxf0e0GAVIi2L1b4iAfo_BEZGOmv-ZVxGXNGEhoSoS1DO0GNzITMIqZvkPuExBKeIOXdi6REKTrxkHK7nG39qnv_AuF9TtwJNRHQt463kHKjT4FQHNrY92Iol97vexCVN23NwhuZLQeZa8JEaqPxJ4KTEgmmzXc9Iz8_dcGqhTRyYWdCVnlkjiQZdFJ77OCWfp0w3zxHrW7svaFd0-Qxn9jswlmbw_PimJJU2E'

# %%
output='json'
Taipei_long, Taipei_lat = 121.597366, 25.105497

url_base = f'https://maps.googleapis.com/maps/api/place/nearbysearch/{output}'

parameters = {'key':'AIzaSyApGI-o8vpq98Ay6qBeFy4YWm3inh_l-OU',
             'location':f'{Taipei_lat},{Taipei_long}',
              'radius':5000,
             'type':'bar'}


para_encoded = urlencode(parameters)
url = f"{url_base}?{para_encoded}"

r = requests.get(url)
results = r.json()['results']

#first_page

name_lst, id_lst, price_level_lst, rating_lst, user_rating_total_lst = [], [], [], [], []
lsts = [name_lst, id_lst, price_level_lst, rating_lst, user_rating_total_lst]
keys = ['name', 'place_id', 'price_level','rating','user_ratings_total']
for n in range(len(results)):
    na_input(lsts, keys, results[n])

times = 10

while times:
    
    time.sleep(5)
    try:

        #next_page   
        next_page = {'key':'AIzaSyApGI-o8vpq98Ay6qBeFy4YWm3inh_l-OU',
                     'pagetoken': r.json()['next_page_token']}
        print(r.json()['next_page_token'])
        para_encoded = urlencode(next_page)

        url = f'{url_base}?{para_encoded}'

        r = requests.get(url)
        results = r.json()['results']

        for n in range(len(results)):
            na_input(lsts, keys, results[n])
            
        times -= 1
        print(times)
    except:
        
        print('no more you can get!')
        break


dic = {}
for key, lst in zip(keys, lsts):
    dic.setdefault(key, lst)

df = pd.DataFrame(dic)

df.head()

'''
#using location bias

locationbias = f"point:{Taipei_lat},{Taipei_long}"
use_circular=False

if use_circular:
    radius = 5000
    locationbias=f"circle:{radius}@{Taipei_lat},{Taipei_long}"
    
#parameters['locationbias'] = locationbias
'''
# Out:
# '\n#using location bias\n\nlocationbias = f"point:{Taipei_lat},{Taipei_long}"\nuse_circular=False\n\nif use_circular:\n    radius = 5000\n    locationbias=f"circle:{radius}@{Taipei_lat},{Taipei_long}"\n    \n#parameters[\'locationbias\'] = locationbias\n'

# %%
r.json()['next_page_token']
# Out:
# 'ATtYBwJdYtXib0lpeJZpzosqe6LhVQLQXWcv_CxzY9ABzQphCV5u8WDdMwU2JISjWMXoZJCrIEGY53lhXWo6yKQdSaRuc9rnfkeCucG3jlD_56NcVS2_4wzSWa19l_6j33spYQdBONZY954EIajTLaLu_2JBbT96Y4zTPRMLVHvJhACtmJzMrQ-l6n6l6f-rbezjOVgpciS56LmGVvxf0e0GAVIi2L1b4iAfo_BEZGOmv-ZVxGXNGEhoSoS1DO0GNzITMIqZvkPuExBKeIOXdi6REKTrxkHK7nG39qnv_AuF9TtwJNRHQt463kHKjT4FQHNrY92Iol97vexCVN23NwhuZLQeZa8JEaqPxJ4KTEgmmzXc9Iz8_dcGqhTRyYWdCVnlkjiQZdFJ77OCWfp0w3zxHrW7svaFd0-Qxn9jswlmbw_PimJJU2E'

# %%
df
# Out:
#                                                  name  \
# 0                                       呼搭啦串燒屋 燒肉便當外送
# 1                                          Le blé dór
# 2                                  SOP by Mastro Cafe
# 3                                                串燒鍋府
# 4                                                荖藤酒窖
# 5                                           酒咖 運動飛鏢酒吧
# 6                         Lazy Point Restaurant & Bar
# 7                                              愛葡悅飲酒藏
# 8                                            陳三Chen*3
# 9                                    CEO Premium Club
# 10                                           Zhangmen
# 11                    水星球潛水酒吧 Water Planet Dive & Bar
# 12  瘋酒屋/瘋Food/內湖美食/內湖居酒屋 /內湖燒烤/內湖resturants/內湖餐廳/內...
# 13          INGE'S Bar&Grill At Taipei Marriott Hotel
# 14                                       Lobby Lounge
# 15                                        Holiday KTV
# ...

# %%
def na_input(lsts, keys, info):
    '''
    the related datatypes of lst and key should be list, 
    while that of info should be dict.
    '''
    for lst, key in zip(lsts, keys):
        try:
            lst.append(info[key])
        except:
            lst.append('N/A')

    return lsts

# %%
import requests

# %%
https://ifoodie.tw/explore/%E5%8F%B0%E5%8C%97%E5%B8%82/list/%E9%A4%90%E9%85%92%E9%A4%A8%2F%E9%85%92%E5%90%A7

# %%
url = 'https://ifoodie.tw/explore/list'

paras_1 = {'':'台北市'}
paras_2 = {'':'餐酒館/酒吧'}
s = f'{urlencode(paras_1)}/list/{urlencode(paras_2)}'.replace('=','')
s
# Out:
# '%E5%8F%B0%E5%8C%97%E5%B8%82/list/%E9%A4%90%E9%85%92%E9%A4%A8%2F%E9%85%92%E5%90%A7'

# %%
r = requests.get('https://ifoodie.tw/explore/%E5%8F%B0%E5%8C%97%E5%B8%82/list/%E9%A4%90%E9%85%92%E9%A4%A8%2F%E9%85%92%E5%90%A7')

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
#  <head>
#   <meta charset="utf-8" class="next-head"/>
#   <link class="next-head" href="/assets/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link class="next-head" href="/assets/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link class="next-head" href="/assets/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link class="next-head" href="/assets/favicons/manifest.json" rel="manifest"/>
#   <link class="next-head" color="#5bbad5" href="/assets/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link class="next-head" href="/assets/favicons/favicon.ico" rel="shortcut icon"/>
#   <meta class="next-head" content="initial-scale=1.0, width=device-width, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#   <meta charset="utf-8" class="next-head"/>
#   <meta class="next-head" content="/assets/favicons/browserconfig.xml" name="msapplication-config"/>
# ...

# %%
dct = {'name': [],'rating': [],'address': []}


for name, rating, address in zip(soup.find_all('a', {'class':"jsx-2133253768 title-text"}),
                                soup.find_all('div', {'class':"jsx-1207467136 text"}),
                                soup.find_all('div', {'class':"jsx-2133253768 address-row"})):
    dct['name'].append(name.text)
    dct['rating'].append(float(rating.text))
    dct['address'].append(address.text)

# %%
df = pd.DataFrame(dct)

# %%
df[df['rating']>=4.5]
# Out:
#                         name  rating                address
# 0   Savior Lounge Bar 救世主小酒館     4.6      臺北市萬華區漢口街二段34巷10號
# 1                  LinK 聯客食堂     4.5       臺北市松山區南京東路四段176號
# 3          K.D Bistro Taipei     4.7      臺北市大安區光復南路346巷21號
# 4           ABV% 加勒比海 精釀啤酒餐廳     4.7    臺北市大安區敦化南路一段233巷61號
# 7     隱士餐酒館The Hermit Bistro     4.6      臺北市大安區光復南路240巷51號
# 10                        誠鮨     4.6        臺北市中山區建國北路二段32號
# 11               阿郎薄皮餃子台式小酒館     4.5  臺北市大安區忠孝東路四段177號2號樓之2
# 13           À Point 艾朋牛排餐酒館     4.5     臺北市信義區忠孝東路五段139號2樓
# 14           ONCE Cafe & Bar     4.6        臺北市萬華區西寧南路82巷2號
# 15   杯盃 PuiBui Cafe & Lounge     4.7      臺北市大安區信義路四段30巷48號

# %%
for n in soup.find_all('a', {'class':"jsx-2133253768 title-text"}):
    print(n.text)
# Out:
# Savior Lounge Bar 救世主小酒館
# LinK 聯客食堂
# 法租界 L.C Française 餐酒館
# K.D Bistro Taipei
# ABV% 加勒比海 精釀啤酒餐廳
# The 58 Bar - 台灣自釀啤酒專賣
# O Steak 歐牛排 法式餐酒館
# 隱士餐酒館The Hermit Bistro
# 黑熊愛跳舞
# Mr. BEAN Taipei
# 誠鮨
# 阿郎薄皮餃子台式小酒館
# 榕RON Cafe
# À Point 艾朋牛排餐酒館
# ONCE Cafe & Bar
# 杯盃 PuiBui Cafe & Lounge

# %%
https://ifoodie.tw/restaurant/5ea996c48c906d139203ece3-Savior-Lounge-Bar-%E6%95%91%E4%B8%96
