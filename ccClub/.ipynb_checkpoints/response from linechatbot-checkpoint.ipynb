# %%
import os
import psycopg2
import flask
from flask import Flask, request, abort, render_template
from linebot import LineBotApi, WebhookHandler
from linebot.exceptions import InvalidSignatureError
from linebot.models import (MessageEvent, TextMessage, TextSendMessage, 
                            PostbackEvent, LocationMessage, FollowEvent, 
                            QuickReply, QuickReplyButton, LocationAction, 
                            URIAction, PostbackAction, TemplateSendMessage, 
                            ButtonsTemplate, CarouselColumn, CarouselTemplate,
                            RichMenu, RichMenuArea, RichMenuBounds, RichMenuSize,
                            FlexSendMessage)

from random import randint
import pandas as pd
from haversine import haversine, Unit
import numpy
import random

# %%
conn = psycopg2.connect(database='d9gnei48mbovh8',
                        user='fusoiorzocvqjt',
                        password='f73bec6757bce818757e1a8894f40ca1a104ffa4459db7a62c424b71263b4bdd',
                        host='ec2-54-211-99-192.compute-1.amazonaws.com',port='5432')
conn.set_session(autocommit=True)

cur = conn.cursor()
cur.execute("select * from taipei_mrt")
all_data = cur.fetchall()


df_mrt = pd.DataFrame({'station_code':[n[0] for n in all_data],
                       'station_name':[n[1] for n in all_data],
                       'lat':[n[2] for n in all_data],
                       'lng':[n[3] for n in all_data]
                      })
'''
cur.close()
conn.close()'''
# Out:
# '\ncur.close()\nconn.close()'

# %%
conn = psycopg2.connect(database='d9gnei48mbovh8',
                        user='fusoiorzocvqjt',
                        password='f73bec6757bce818757e1a8894f40ca1a104ffa4459db7a62c424b71263b4bdd',
                        host='ec2-54-211-99-192.compute-1.amazonaws.com',port='5432')
conn.set_session(autocommit=True)

cur = conn.cursor()
cur.execute("""create table if not exists account(
               user_id text not null unique,
               back_home boolean not null,
               game_room boolean not null);""")
conn.commit()

# %%
#connecting database
conn = psycopg2.connect(database='d9gnei48mbovh8',
                        user='fusoiorzocvqjt',
                        password='f73bec6757bce818757e1a8894f40ca1a104ffa4459db7a62c424b71263b4bdd',
                        host='ec2-54-211-99-192.compute-1.amazonaws.com',port='5432')
conn.set_session(autocommit=True)

#bar_info
cur = conn.cursor()
cur.execute("select * from bar")
all_data = cur.fetchall()
df_bar = pd.DataFrame({'name':[n[0] for n in all_data], 'rating':[n[1] for n in all_data], 
                       'address':[n[2] for n in all_data],'price':[n[3] for n in all_data],
                       'lat':[n[6] for n in all_data],'lng':[n[7] for n in all_data],
                       'review':[n[8] for n in all_data]
                  })


#image_info
lst = range(1, 33)
a, b, c, d, e= random.sample(lst,5)

cur.execute(f'select name, image_{a}, image_{b}, image_{c}, image_{d}, image_{e} from bar_image;')
all_data = cur.fetchall()

df_image = pd.DataFrame({'name':[n[0] for n in all_data],'image_0':[n[1] for n in all_data],
                        'image_1':[n[2] for n in all_data], 'image_2':[n[3] for n in all_data],
                        'image_3':[n[4] for n in all_data], 'image_4':[n[5] for n in all_data]})


#merge two dataframe, and get rid of duplicated ones
df = pd.merge(df_bar,df_image,on='name')
df.drop(df[df['name'].duplicated()].index, inplace=True)


#mrt_info
cur.execute("select * from taipei_mrt")
all_data = cur.fetchall()


df_mrt = pd.DataFrame({'station_code':[n[0] for n in all_data], 'station_name':[n[1] for n in all_data],
                       'lat':[n[2] for n in all_data], 'lng':[n[3] for n in all_data]
                      })

#cur.close()
#conn.close()


df_shortest, df_cost, df_rating = None, None, None


#handle review
def convert_review_to_json(review):
    review = review.replace('[','')
    review = review.replace(']','')
    review = review.replace("\'",'\"')
    review = eval(review)
    json.loads(json.dumps(review))
    return review


#終極密碼
lowest = 1
highest = 100
answer = randint(2, 99)
guess_round = 0



app = Flask(__name__)
line_bot_api = LineBotApi("ZRenw4zKciZ66CnPJYuRwqq35sQ1H/MVamEplfr1DTvRYHML1IVNsR9kJXPvccFTiMvyCx0fElkMm6cTvrvTa8GbpZeNHbHr/ww4CJyIvu1UOH91AvEvayalWceli7QM7+lt3ivY2UbjOm7sMxch5AdB04t89/1O/w1cDnyilFU=")
handler = WebhookHandler("ef182b4b1e515da5c715c480052207aa")


@app.route('/')
def index():
    return render_template('index.html', latitude=25.03, longitude=121.55)

@app.route('/<latitude>/<longitude>')
def index_location(latitude, longitude):
    return render_template('index.html', latitude=latitude, longitude=longitude)

@app.route("/callback", methods=['POST'])
def callback():

    signature = request.headers['X-Line-Signature']

    body = request.get_data(as_text=True)
    app.logger.info("Request body: "+ body)

    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        abort(400)

    return 'OK'

#welcome message
@handler.add(FollowEvent)
def follow_event(event):
    global cur
    
    user=event.source.user_id
    
    record = (f'{event.source.user_id}','false', 'false')
    table_columns = '(user_id, back_home, game_room)'
    
    try:
        postgres_insert_query=f"""insert into account {table_columns} 
                                values (%s, %s, %s)"""
        cur.execute(postgres_insert_query, record)
    except:
        print(f'{event.source.user_id} already exist, processing the updates')
        
        user = event.source.user_id
        
        postgres_insert_query = f"""update account set back_home = 'f', game_room = 'f'
        where user_id = %s"""
        cur.execute(postgres_insert_query, (user,))
        print('Successfully updates')

    line_bot_api.reply_message(
        event.reply_token,
        FlexSendMessage(
            alt_text='hello',
            contents={
  "type": "bubble",
  "size": "mega",
  "hero": {
    "type": "image",
    "url": "https://no37elephant.github.io/logo-03.png",
    "size": "full",
    "aspectRatio": "20:15",
    "aspectMode": "cover",
    "offsetTop": "none",
    "margin": "none"
  },
  "body": {
    "type": "box",
    "layout": "vertical",
    "contents": [
      {
        "type": "text",
        "text": "【 Bar.py | 你的酒吧導航 】",
        "weight": "bold",
        "size": "lg",
        "color": "#464F69"
      },
      {
        "type": "box",
        "layout": "vertical",
        "margin": "lg",
        "spacing": "sm",
        "contents": [
          {
            "type": "box",
            "layout": "vertical",
            "spacing": "sm",
            "contents": []
          },
          {
            "type": "box",
            "layout": "vertical",
            "spacing": "sm",
            "contents": [
              {
                "type": "text",
                "text": "全台最完整的酒吧資訊就在這裡 🍺 要微",
                "size": "xs",
                "flex": 1,
                "margin": "none",
                "adjustMode": "shrink-to-fit"
              },
              {
                "type": "text",
                "text": "醺還是買醉，Bar.py都能找到最合你意的！",
                "size": "xs",
                "flex": 1,
                "margin": "sm",
                "adjustMode": "shrink-to-fit"
              }
            ]
          }
        ]
      },
      {
        "type": "separator",
        "margin": "lg"
      },
      {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "使用說明",
            "margin": "md",
            "size": "md",
            "color": "#646f82"
          },
          {
            "type": "text",
            "text": "1. 告訴我們你的位置",
            "margin": "sm",
            "size": "sm"
          },
          {
            "type": "text",
            "text": "2. 按條件篩選酒吧",
            "margin": "sm",
            "size": "sm"
          },
          {
            "type": "text",
            "text": "3. 瀏覽我們的精選名單",
            "margin": "sm",
            "size": "sm"
          },
          {
            "type": "text",
            "text": "4. 前往酒吧！",
            "margin": "sm",
            "size": "sm"
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "點我試試看",
              "text": "我想試試看"
            },
            "margin": "md",
            "style": "link",
            "color": "#03245c"
          }
        ]
      }
    ]
  }
}
    ))

@handler.add(MessageEvent, message=TextMessage)
def handle_message(event):
    global answer, lowest, highest, guess_round
    
    
    if event.message.text == '我想試試看':
        line_bot_api.reply_message(
        event.reply_token,
        TextSendMessage(text='好～告訴我你的位置吧！\n \n對了！點擊下方「理性癮酒」可以重新開始，也有更多驚喜服務！😈',
                       quick_reply=QuickReply(items=[
                           QuickReplyButton(action=LocationAction(label='I am here.'))

            ])))
        
        
    if '@' in event.message.text:
        
        if event.message.text[0] == '@':
            guess = event.message.text.split('@')[1]
            print(answer)
            try:
                guess = int(guess)
                if guess <= lowest or guess >= highest:
                    line_bot_api.reply_message(
                    event.reply_token,
                    TextSendMessage(text = f'醉了嗎？密碼介於{lowest}與{highest}之間誒！')) 
                    guess_round += 1
                elif guess < answer:
                    lowest = guess
                    line_bot_api.reply_message(
                    event.reply_token,
                    TextSendMessage(text = f'密碼介於{lowest}與{highest}之間！'))
                    guess_round += 1
                elif guess > answer:
                    highest = guess
                    line_bot_api.reply_message(
                    event.reply_token,
                    TextSendMessage(text = f'密碼介於{lowest}與{highest}之間！'))
                    guess_round += 1

                elif guess == answer:

                    if guess_round < 5:
                        line_bot_api.reply_message(
                        event.reply_token,
                        TextSendMessage(text = f'恭喜答對了，只猜{guess_round}次就成功了，看樣子喝不夠！喝！喝！喝！'))
                    elif guess_round >= 5 and guess_round < 10:
                        line_bot_api.reply_message(
                        event.reply_token,
                        TextSendMessage(text = f'恭喜答對了，你猜了{guess_round}次，\應該還能再喝一點喔！'))
                    else:
                        line_bot_api.reply_message(
                        event.reply_token,
                        TextSendMessage(text = f'答對了！不過猜了{guess_round}次才成功，該回家囉！'))

                    lowest = 1
                    highest = 100
                    guess_round = 0
                    answer = randint(2, 99)
                    print(event.source.user_id)



            except:
                guess_round += 1
                line_bot_api.reply_message(
                    event.reply_token,
                    TextSendMessage(text = f'醉了嗎？要猜數字誒，『{guess}』不是數字！再猜一次，密碼介於{lowest}與{highest}之間。'))
        else:
            line_bot_api.reply_message(
                    event.reply_token,
                    TextSendMessage(text = f'醉了嗎？@要在前面喔！例如 @56 或是 @78！再猜一次，密碼介於{lowest}與{highest}之間。'))


@handler.add(MessageEvent, message=LocationMessage)
def handle_location(event):
    
    print(event)
    
    global df, df_shortest, df_cost, df_rating, df_mrt, cur
    
    user_id = event.source.user_id
        
    postgres_insert_query = f"""select back_home from account where user_id = %s"""
    cur.execute(postgres_insert_query, (user_id,))
    state = cur.fetchone()[0]
    print(state)
    
    latitude = event.message.latitude
    longitude = event.message.longitude
    
    #計算距離
    user = (latitude, longitude)
    
    if state:
        df_mrt['dist'] = df_mrt.apply(lambda x: haversine(user, (x['lat'], x['lng'])), axis=1)
        df_mrt_shortest = df_mrt.sort_values(by=['dist'])
        
        line_bot_api.reply_message(
            event.reply_token,
            TemplateSendMessage(
                alt_text='Button',
                template=ButtonsTemplate(
                title='最近的捷運站',
                text=df_mrt_shortest['station_name'].iloc[0],
                actions=[
                    URIAction(
                        label='這樣去！',
                        uri=f"https://www.google.com/maps/search/?api=1&query={df_mrt_shortest['lat'].iloc[0]},{df_mrt_shortest['lng'].iloc[0]}"
                    )]
                )
            ))
        
        df_mrt.drop(['dist'], axis=1, inplace=True)
        
        postgres_insert_query = f"""update account set back_home = 'f' where user_id = %s"""
        cur.execute(postgres_insert_query, (user_id,))
        
    else:
        df['dist'] = df.apply(lambda x: haversine(user, (x['lat'], x['lng'])), axis=1)

        #最快醉
        df_shortest = df.sort_values(by=['dist']).head(10)
        #最便宜
        df_cost = df_shortest.sort_values(by=['price'])
        #最推薦
        df_rating = df_shortest.sort_values(by=['rating'], ascending=False)

        line_bot_api.reply_message(
            event.reply_token,
            TemplateSendMessage(
                alt_text='Buttons template',
                template=ButtonsTemplate(
                thumbnail_image_url='https://no37elephant.github.io/buttontemplate-04.png',
                text='你想怎麼喝！',
                actions=[
                    PostbackAction(
                        label='喝近的',
                        data='critera=shortest'
                    ),
                    PostbackAction(
                        label='喝便宜的',
                        data='criteria=cheapest'
                    ),
                    PostbackAction(
                        label='喝評分高的',
                        data='criteria=hotest'),
                    URIAction(
                        label='自己找不用推薦謝謝',
                        uri=f'https://ccbarbarbar.herokuapp.com/{latitude}/{longitude}'
                    )])
            )



        )
        df.drop(['dist'], axis=1, inplace=True)


@handler.add(PostbackEvent)
def handle_postback(event):
    
    global df_shortest, df_cost, df_rating, df, cur
    print(event.postback.data)
    
    try:
        index = int(event.postback.data)
        review = df.iloc[index, 6]
        print(review)
        review = convert_review_to_json(review)
        review = random.sample(review,3)
        print(review)
        print(f"""{review[0]['author_name']}說: {review[0]['text']} """)
        
        line_bot_api.reply_message(
        event.reply_token,
        TextSendMessage(text=f"{review[0]['author_name']}說: {review[0]['text']}"))
        
    except:
        if event.postback.data == '重頭開始':
            line_bot_api.reply_message(
                event.reply_token,
                FlexSendMessage(alt_text='hello',
                contents={
  "type": "bubble",
  "size": "mega",
  "body": {
    "type": "box",
    "layout": "vertical",
    "contents": [
      {
        "type": "text",
        "text": "【 Bar.py | 你的酒吧導航 】",
        "weight": "bold",
        "size": "lg",
        "color": "#464F69"
      },
      {
        "type": "box",
        "layout": "vertical",
        "margin": "lg",
        "spacing": "sm",
        "contents": [
          {
            "type": "box",
            "layout": "vertical",
            "spacing": "sm",
            "contents": []
          },
          {
            "type": "box",
            "layout": "vertical",
            "spacing": "xs",
            "contents": [
              {
                "type": "text",
                "text": "全台最完整的酒吧資訊就在這裡 🍺 要微醺",
                "size": "xs",
                "flex": 1,
                "margin": "none",
                "adjustMode": "shrink-to-fit"
              },
              {
                "type": "text",
                "text": "還是買醉，Bar.py都能找到最合你意的！",
                "size": "xs",
                "flex": 1,
                "margin": "sm",
                "adjustMode": "shrink-to-fit"
              }
            ]
          }
        ]
      },
      {
        "type": "separator",
        "margin": "lg"
      },
      {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "使用說明",
            "margin": "md",
            "size": "md",
            "color": "#646f82"
          },
          {
            "type": "text",
            "text": "1. 告訴我們你的位置",
            "margin": "sm",
            "size": "sm"
          },
          {
            "type": "text",
            "text": "2. 按條件篩選酒吧",
            "margin": "sm",
            "size": "sm"
          },
          {
            "type": "text",
            "text": "3. 瀏覽我們的精選名單",
            "margin": "sm",
            "size": "sm"
          },
          {
            "type": "text",
            "text": "4. 前往酒吧！",
            "margin": "sm",
            "size": "sm"
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "點我試試看",
              "text": "我想試試看"
            },
            "margin": "md",
            "style": "link",
            "color": "#03245c",
            "adjustMode": "shrink-to-fit"
          }
        ]
      }
    ]
  }
}
                            ))
           
        if event.postback.data == '回家':
            
            user = event.source.user_id
            postgres_insert_query = f"""update account set back_home = 't'
            where user_id = %s"""
            cur.execute(postgres_insert_query, (user,))            
            
            line_bot_api.reply_message(
            event.reply_token,
            TemplateSendMessage(
                alt_text='回家囉！',
                template=ButtonsTemplate(
                title='回家嗎？',
                text='我幫你找最近的捷運站！',
                actions=[LocationAction(
                label='告訴我你在哪？')])))
        
        
    
        if event.postback.data == '終極密碼':
            line_bot_api.reply_message(
            event.reply_token,
            TextSendMessage(text=f'來測測看你的酒醉程度，來玩終極密碼吧，看你要花多少回合猜對我心中的數字，數字是整數喔！密碼介於{lowest}與{highest}之間，注意：輸入的答案要以@開頭喔，如 @56 不要忘記了！'))

        if event.postback.data=='critera=shortest':
            contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_shortest['image_0'].iloc[0]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_shortest['name'].iloc[0]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[0]},{df_shortest['lng'].iloc[0]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_shortest.index[0]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.1",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },
  {
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_shortest['image_0'].iloc[1]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_shortest['name'].iloc[1]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[1]},{df_shortest['lng'].iloc[1]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_shortest.index[1]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.2",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_shortest['image_0'].iloc[2]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_shortest['name'].iloc[2]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[2]},{df_shortest['lng'].iloc[2]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_shortest.index[2]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.3",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_shortest['image_0'].iloc[3]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_shortest['name'].iloc[3]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[3]},{df_shortest['lng'].iloc[3]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_shortest.index[3]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.4",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_shortest['image_0'].iloc[4]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_shortest['name'].iloc[4]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[4]},{df_shortest['lng'].iloc[4]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_shortest.index[4]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.5",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    }]
}
            
            print(event)
            line_bot_api.reply_message(
            event.reply_token,
            FlexSendMessage(
                alt_text='hello',
                contents=contents
            ))
        if event.postback.data=='criteria=cheapest':
            contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_cost['image_0'].iloc[0]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_cost['name'].iloc[0]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_cost['lat'].iloc[0]},{df_cost['lng'].iloc[0]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_cost.index[0]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.1",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },
  {
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_cost['image_0'].iloc[1]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_cost['name'].iloc[1]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_cost['lat'].iloc[1]},{df_cost['lng'].iloc[1]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_cost.index[1]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.2",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_cost['image_0'].iloc[2]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_cost['name'].iloc[2]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_cost['lat'].iloc[2]},{df_cost['lng'].iloc[2]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_cost.index[2]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.3",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_cost['image_0'].iloc[3]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_cost['name'].iloc[3]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_cost['lat'].iloc[3]},{df_cost['lng'].iloc[3]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_cost.index[3]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.4",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_cost['image_0'].iloc[4]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_cost['name'].iloc[4]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_cost['lat'].iloc[4]},{df_cost['lng'].iloc[4]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_cost.index[4]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.5",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    }]
}
            
            print(event)
            line_bot_api.reply_message(
            event.reply_token,
            FlexSendMessage(
                alt_text='hello',
                contents=contents
            ))

        if event.postback.data=='criteria=hotest':
            contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_rating['image_0'].iloc[0]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_rating['name'].iloc[0]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_rating['lat'].iloc[0]},{df_rating['lng'].iloc[0]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_rating.index[0]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.1",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },
  {
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_cost['image_0'].iloc[1]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_rating['name'].iloc[1]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_rating['lat'].iloc[1]},{df_rating['lng'].iloc[1]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_rating.index[1]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.2",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_rating['image_0'].iloc[2]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_rating['name'].iloc[2]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_rating['lat'].iloc[2]},{df_rating['lng'].iloc[2]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_rating.index[2]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.3",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_rating['image_0'].iloc[3]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_rating['name'].iloc[3]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_rating['lat'].iloc[3]},{df_rating['lng'].iloc[3]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_rating.index[3]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.4",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_rating['image_0'].iloc[4]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{df_rating['name'].iloc[4]}",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_rating['lat'].iloc[4]},{df_rating['lng'].iloc[4]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_rating.index[4]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.5",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334bcc",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    }]
}
            
            print(event)
            line_bot_api.reply_message(
            event.reply_token,
            FlexSendMessage(
                alt_text='hello',
                contents=contents
            ))

           
        if event.postback.data=="隨機推薦":
            print('i am here')
            index = random.randint(0, len(df)-1)
            url = df['image_0'].iloc[index]
            price = int(df['price'].iloc[index])
            name = df['name'].iloc[index]
            rating = df['rating'].iloc[index]
            address= df['address'].iloc[index]
            
            contents={
  "type": "bubble",
  "body": {
    "type": "box",
    "layout": "vertical",
    "contents": [
      {
        "type": "image",
        "url": f"{url}",
        "size": "full",
        "aspectMode": "cover",
        "aspectRatio": "1:1",
        "gravity": "center",
        "action": {
          "type": "uri",
          "label": "action",
          "uri": f"https://www.google.com/maps/search/?api=1&query={df['lat'].iloc[index]},{df['lng'].iloc[index]}"
        }
      },
      {
        "type": "box",
        "layout": "vertical",
        "contents": [],
        "position": "absolute",
        "background": {
          "type": "linearGradient",
          "angle": "0deg",
          "endColor": "#00000000",
          "startColor": "#00000099"
        },
        "width": "100%",
        "height": "40%",
        "offsetBottom": "0px",
        "offsetStart": "0px",
        "offsetEnd": "0px"
      },
      {
        "type": "box",
        "layout": "horizontal",
        "contents": [
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "horizontal",
                "contents": [
                  {
                    "type": "text",
                    "text": f"{name}",
                    "size": "xl",
                    "color": "#ffffff"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "baseline",
                "contents": [
                  {
                    "type": "text",
                    "text": f"地址：{address}",
                    "color": "#fffcfc"
                  }
                ],
                "spacing": "xs"
              },
              {
                "type": "box",
                "layout": "horizontal",
                "contents": [
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "text",
                        "text": f"NT${price}",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "end"
                      }
                    ],
                    "flex": 0,
                    "spacing": "lg"
                  }
                ]
              }
            ],
            "spacing": "xs"
          }
        ],
        "position": "absolute",
        "offsetBottom": "0px",
        "offsetStart": "0px",
        "offsetEnd": "0px",
        "paddingAll": "20px"
      }
    ],
    "paddingAll": "0px"
  }
}
                
            line_bot_api.reply_message(
                    event.reply_token,
                    FlexSendMessage(
                    alt_text='Look what I get for you!',
                    contents=contents)
                    )


if __name__ == "__main__":
    app.config["JSON_AS_ASCII"] = False
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2020-12-23 17:18:31,764] ERROR in app: Exception on /callback [POST]
# Traceback (most recent call last):
#   File "<ipython-input-1060-44d580ed2b8f>", line 409, in handle_postback
#     index = int(event.postback.data)
# ValueError: invalid literal for int() with base 10: 'critera=shortest'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1060-44d580ed2b8f>", line 92, in callback
#     handler.handle(body, signature)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/linebot/webhook.py", line 260, in handle
#     self.__invoke_func(func, event, payload)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/linebot/webhook.py", line 272, in __invoke_func
#     func(event)
#   File "<ipython-input-1060-44d580ed2b8f>", line 571, in handle_postback
#     "url": f"{df_shortest['image_0'].iloc[0]}",
# TypeError: 'NoneType' object is not subscriptable
# ERROR:__main__:Exception on /callback [POST]
# Traceback (most recent call last):
#   File "<ipython-input-1060-44d580ed2b8f>", line 409, in handle_postback
#     index = int(event.postback.data)
# ValueError: invalid literal for int() with base 10: 'critera=shortest'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1060-44d580ed2b8f>", line 92, in callback
#     handler.handle(body, signature)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/linebot/webhook.py", line 260, in handle
#     self.__invoke_func(func, event, payload)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/linebot/webhook.py", line 272, in __invoke_func
#     func(event)
#   File "<ipython-input-1060-44d580ed2b8f>", line 571, in handle_postback
#     "url": f"{df_shortest['image_0'].iloc[0]}",
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [23/Dec/2020 17:18:31] "POST /callback HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [23/Dec/2020 17:18:31] "POST /callback HTTP/1.1" 500 -
# critera=shortest
# 重頭開始
# 127.0.0.1 - - [23/Dec/2020 17:18:46] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Dec/2020 17:18:46] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Dec/2020 17:18:47] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Dec/2020 17:18:47] "POST /callback HTTP/1.1" 200 -
# 重頭開始
# 127.0.0.1 - - [23/Dec/2020 17:18:49] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Dec/2020 17:18:49] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Dec/2020 17:18:50] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Dec/2020 17:18:50] "POST /callback HTTP/1.1" 200 -
# {"message": {"address": "106\u53f0\u7063\u53f0\u5317\u5e02\u5927\u5b89\u5340\u84b2\u8475\u9053", "id": "13252652568585", "latitude": 25.018708834700096, "longitude": 121.53767135338528, "type": "location"}, "mode": "active", "replyToken": "d7dfd9a092884569a2dea1456048df2f", "source": {"type": "user", "userId": "Ub0bcf3a6d935bd8804e49fc576322cab"}, "timestamp": 1608715133344, "type": "message"}
# 127.0.0.1 - - [23/Dec/2020 17:18:52] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Dec/2020 17:18:52] "POST /callback HTTP/1.1" 200 -
# False
# 127.0.0.1 - - [23/Dec/2020 17:18:55] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Dec/2020 17:18:55] "POST /callback HTTP/1.1" 200 -
# critera=shortest
# {"mode": "active", "postback": {"data": "critera=shortest"}, "replyToken": "1b39e97876264e798f0d9b05b2f17ec2", "source": {"type": "user", "userId": "Ub0bcf3a6d935bd8804e49fc576322cab"}, "timestamp": 1608715135438, "type": "postback"}

# %%
headers = headers = {'Authorization':'Bearer ZRenw4zKciZ66CnPJYuRwqq35sQ1H/MVamEplfr1DTvRYHML1IVNsR9kJXPvccFTiMvyCx0fElkMm6cTvrvTa8GbpZeNHbHr/ww4CJyIvu1UOH91AvEvayalWceli7QM7+lt3ivY2UbjOm7sMxch5AdB04t89/1O/w1cDnyilFU=',
          'Content-Type':'aaplication/json'}

rich_menu_to_create = RichMenu(
    size=RichMenuSize(width=2500, height=1686),
    selected=False,
    name="Nice richmenu_4",
    chat_bar_text="理性癮酒",
    areas=[RichMenuArea(
            bounds=RichMenuBounds(x=0, y=843, width=833, height=843),
            action=PostbackAction(label='Bar Map', data='回家')),
          RichMenuArea(
            bounds=RichMenuBounds(x=833, y=843, width=833, height=843),
            action=PostbackAction(label='message', data='隨機推薦')),
          RichMenuArea(
            bounds=RichMenuBounds(x=1666, y=843, width=834, height=843),
            action=PostbackAction(label='message', data='終極密碼')),
          RichMenuArea(
            bounds=RichMenuBounds(x=0, y=0, width=2500, height=843),
            action=PostbackAction(label='message', data='重頭開始')),
           
          
          ])

rich_menu_id = line_bot_api.create_rich_menu(rich_menu_to_create)

# %%
rich_menu_id
# Out:
# 'richmenu-51f27986000e40c4ef584e6539c0905d'

# %%
pwd
# Out:
# '/Users/sheng-chih/Documents/GitHub/ccClubFall2020/ccClub'

# %%
with open('richmenu.png', 'rb') as f:
    line_bot_api.set_rich_menu_image(rich_menu_id, "image/png", f)

# %%
headers = {'Authorization':'Bearer ZRenw4zKciZ66CnPJYuRwqq35sQ1H/MVamEplfr1DTvRYHML1IVNsR9kJXPvccFTiMvyCx0fElkMm6cTvrvTa8GbpZeNHbHr/ww4CJyIvu1UOH91AvEvayalWceli7QM7+lt3ivY2UbjOm7sMxch5AdB04t89/1O/w1cDnyilFU=',
          'Content-Type':'aaplication/json'}

req = requests.request('POST', f'https://api.line.me/v2/bot/user/all/richmenu/{rich_menu_id}',
                      headers=headers)

print(req.text)
# Out:
# {}

# %%
mrt = pd.read_csv('northern-taiwan.csv', sep=',')

# %%
conn = psycopg2.connect(database='d9gnei48mbovh8',
                        user='fusoiorzocvqjt',
                        password='f73bec6757bce818757e1a8894f40ca1a104ffa4459db7a62c424b71263b4bdd',
                        host='ec2-54-211-99-192.compute-1.amazonaws.com',port='5432')
conn.set_session(autocommit=True)

cur = conn.cursor()

create_table_query = """create table taipei_mrt(
    station_code text not null,
    station_name text not null,
    station_lat float not null,
    station_lng float not null
    );"""

cur.execute(create_table_query)




records=[]
for i in range(len(mrt)):
    records.append((f'{mrt.iloc[i,0]}',f'{mrt.iloc[i,2]}',f'{mrt.iloc[i,7]}',f'{mrt.iloc[i,8]}'))
table_columns='(station_code, station_name, station_lat, station_lng)'
postgres_insert_query=f"""insert into taipei_mrt {table_columns}
                            values (%s, %s, %s, %s)"""

cur.executemany(postgres_insert_query, records)
conn.commit()

count = cur.rowcount
print(count)
# Out:
# 156

# %%
cur.execute("""SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public'
ORDER BY table_name;""")

for n in cur:
    print(n)
# Out:
# ('bar',)
# ('taipei_mrt',)

# %%
mrt.head()
# Out:
#   station_code construction_id station_name_tw    station_name_en line_code  \
# 0         BR01            BR13             動物園         Taipei Zoo        BR
# 1         BR02            BR12              木柵              Muzha        BR
# 2         BR03            BR11            萬芳社區  Wanfang Community        BR
# 3         BR04            BR10            萬芳醫院   Wanfang Hospital        BR
# 4         BR05             BR9              辛亥             Xinhai        BR
#
#   line_name          address        lat         lon
# 0       文湖線   台北市文山區新光路二段32號  24.998197  121.579338
# 1       文湖線  台北市文山區木柵路四段135號  24.998241  121.573145
# 2       文湖線     台北市文山區萬芳路60號  24.998585  121.568102
# 3       文湖線  台北市文山區興隆路三段113號  24.999386  121.558152
# 4       文湖線  台北市文山區辛亥路四段128號  25.005475  121.557107

# %%
from random import randint

# %%
for x in photo[photo['0'].isnull()]['0'].index:
    y = randint(0,19)
    photo['0'].iloc[x] =image_url[y]

# %%
for n in lst:
    for x in photo[photo[n].isnull()][n].index:
        y = randint(0,19)
        photo[n].iloc[x] = image_url[y]

# %%
photo.shape
# Out:
# (741, 34)

# %%
#image_database
conn = psycopg2.connect(database='d9gnei48mbovh8',
                        user='fusoiorzocvqjt',
                        password='f73bec6757bce818757e1a8894f40ca1a104ffa4459db7a62c424b71263b4bdd',
                        host='ec2-54-211-99-192.compute-1.amazonaws.com',port='5432')
conn.set_session(autocommit=True)

cur = conn.cursor()

create_table_query = """create table if not exists bar_image(
    name text not null, image_0 text not null, image_1 text not null, image_2 text not null, image_3 text not null,
    image_4 text not null, image_5 text not null, image_6 text not null, image_7 text not null, image_8 text not null,
    image_9 text not null, image_10 text not null, image_11 text not null, image_12 text not null,image_13 text not null,
    image_14 text not null, image_15 text not null, image_16 text not null, image_17 text not null, image_18 text not null,
    image_19 text not null, image_20 text not null, image_21 text not null, image_22 text not null, image_23 text not null,
    image_24 text not null, image_25 text not null, image_26 text not null, image_27 text not null, image_28 text not null,
    image_29 text not null, image_30 text not null, image_31 text not null, image_32 text not null);"""

cur.execute(create_table_query)



#insert data
records=[]

for i in range(len(photo)):
    records.append((f'{photo.iloc[i,0]}',f'{photo.iloc[i,1]}',f'{photo.iloc[i,2]}',f'{photo.iloc[i,3]}',
                    f'{photo.iloc[i,4]}',f'{photo.iloc[i,5]}',f'{photo.iloc[i,6]}',f'{photo.iloc[i,7]}',
                    f'{photo.iloc[i,8]}',f'{photo.iloc[i,9]}',f'{photo.iloc[i,10]}',f'{photo.iloc[i,11]}',
                    f'{photo.iloc[i,12]}',f'{photo.iloc[i,13]}',f'{photo.iloc[i,14]}',f'{photo.iloc[i,15]}',
                    f'{photo.iloc[i,16]}',f'{photo.iloc[i,17]}',f'{photo.iloc[i,18]}',f'{photo.iloc[i,19]}',
                    f'{photo.iloc[i,20]}',f'{photo.iloc[i,21]}',f'{photo.iloc[i,22]}',f'{photo.iloc[i,23]}',
                    f'{photo.iloc[i,24]}',f'{photo.iloc[i,25]}',f'{photo.iloc[i,26]}',f'{photo.iloc[i,27]}',
                    f'{photo.iloc[i,28]}',f'{photo.iloc[i,29]}',f'{photo.iloc[i,30]}',f'{photo.iloc[i,31]}',
                    f'{photo.iloc[i,32]}',f'{photo.iloc[i,33]}'))

    
#bar_image_table_columns

string = 'name'
image_column_lst = []
for n in range(33):
    image_column_lst.append(f'image_{n}')    
','.join(image_column_lst)
table_columns = f"(name,{','.join(image_column_lst)})" 


postgres_insert_query=f"""insert into bar_image {table_columns}
                            values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
                            # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""

cur.executemany(postgres_insert_query, records)
conn.commit()

count = cur.rowcount
print(count)
# Out:
# 741

# %%
cur.execute(f'select name image_{a}, image_{b}, image_{c}, image_{d}, image_{e} from bar_image;')

# %%
#隨機選取不同的照片

import random
lst = range(1, 34)
a, b, c, d, e= random.sample(lst,5)

cur.execute(f'select name, image_{a}, image_{b}, image_{c}, image_{d}, image_{e} from bar_image;')
all_data = cur.fetchall()

df_image = pd.DataFrame({'name':[n[0] for n in all_data],'image_0':[n[1] for n in all_data],
                        'image_1':[n[2] for n in all_data], 'image_2':[n[3] for n in all_data],
                        'image_3':[n[4] for n in all_data], 'image_4':[n[5] for n in all_data]})

#get bar geo data from database
cur.execute("select * from bar")
all_data = cur.fetchall()
df_bar = pd.DataFrame({'name':[n[0] for n in all_data], 'rating':[n[1] for n in all_data], 
                   'address':[n[2] for n in all_data],'price':[n[3] for n in all_data],
                   'lat':[n[6] for n in all_data],'lng':[n[7] for n in all_data]
                  })

#merge two dataframe, and get rid of duplicated ones
df = pd.merge(df_bar,df_image,on='name')
df.drop(df[df['name'].duplicated()].index, inplace=True)
len(df)
# Out:
# 738

# %%
conn = psycopg2.connect(database='d9gnei48mbovh8',
                        user='fusoiorzocvqjt',
                        password='f73bec6757bce818757e1a8894f40ca1a104ffa4459db7a62c424b71263b4bdd',
                        host='ec2-54-211-99-192.compute-1.amazonaws.com',port='5432')
conn.set_session(autocommit=True)

#bar info
cur = conn.cursor()
cur.execute("select * from bar")
all_data = cur.fetchall()
df = pd.DataFrame({'name':[n[0] for n in all_data], 'rating':[n[1] for n in all_data], 
                   'address':[n[2] for n in all_data],'price':[n[3] for n in all_data],
                   'lat':[n[6] for n in all_data],'lng':[n[7] for n in all_data], 'review':[n[8] for n in all_data]
                  })

# %%
comments = all_data[0][-2].replace('[','')
comments = comments.replace(']','')

# %%
comments = comments.replace("\'",'\"')

# %%
x = eval(comments)

# %%
def convert_review_to_json(review):
    review = review.replace('[','')
    review = review.replace(']','')
    review = review.replace("\'",'\"')
    review = eval(review)
    json.loads(json.dumps(review))
    return review

# %%
df_shortest.index[0]
# Out:
# 408

# %%
f"""{review[0]['author_name']}說: {review[0]['text']} {review[1]['author_name']}說: {review[1]['text']} {review[2]['author_name']}說: {review[2]['text']}
"""
# Out:
# 'Rubio Chou說: 主推茶酒，非常特別\n經典系列也夠水準。\n無話可說，無可挑剔。\n以後回來探親肯定再刷的地方。 Yujie說: 伯爵茶以及烏龍茶加重酒精非常順口好喝，茶香味濃厚！店裡有香氛沒有煙味 氣氛非常好，然後可以帶外食叫熊貓唷🤤推薦大家來～ 劉芯妤說: 八天德很ㄎㄧㄤ，很會聊\n完全不尷尬\n酒也超讚的啦☺️\n'

# %%
count = []
for n in range(len(df)):
    try:
        convert_review_to_json(df.iloc[n,6])
    except:
        count.append(n)

# %%
print(count)
# Out:
# [5, 10, 50, 55, 71, 83, 86, 90, 104, 185, 210, 237, 262, 265, 282, 303, 339, 358, 390, 392, 408, 410, 421, 458, 472, 481, 522, 529, 562, 615, 619, 634, 660, 670, 676, 679, 684, 714]

# %%
cur.fetchone()[0]
# Out:
# False

# %%
cur.execute("drop table account")

# %%
print(count)
# Out:
# [5, 10, 50, 55, 71, 83, 86, 90, 104, 185, 210, 237, 262, 265, 282, 303, 339, 358, 390, 392, 408, 410, 421, 458, 472, 481, 522, 529, 562, 615, 619, 634, 660, 670, 676, 679, 684, 714]

# %%
review = df['review'].iloc[714]
review = review.replace("'",'"')
review = review.replace('\\n','')
review
# Out:
# '[{"author_name": "Sky Cho", "author_url": "https://www.google.com/maps/contrib/106032870450419582965/reviews", "language": "zh-Hant", "profile_photo_url": "https://lh3.googleusercontent.com/-UPkijgiNjl8/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclet6gomd5BxkX6bWhyvYaz7jalew/s128-c0x00000000-cc-rp-mo/photo.jpg", "rating": 3, "relative_time_description": "1 個月前", "text": "覺得以前的菜色比較好吃從南部到北部玩每次都會想來這！這是第二次來訪餐廳～但有點小失望...我來之前有訂狗狗餐從小份450$變1000$我是覺得無所謂...但是1000$的餐點是美國牛一開始覺得份量1000$應該是多的或更美味...但是1000$蔬菜一點點、肉肉一點點...沒有任何東西...感覺比我們的前菜不如也不如主菜...瞬間覺得之前450$她吃的比較開心...覺得帶她去吃高級和牛比較划算～餐點部份前菜還ok主菜真的有點太鹹了！畢竟我們不是外國人調味不會吃太重好可惜～我是個喜歡帶狗狗品嚐高級料理的人這次真的失望～難得有這樣的餐廳希望你們可以更好～～～～所以只給3星這樣會覺得不如去 L’ATELIER Joël Robuchon的味道和價位比較符合期望！這樣才符合vp 質～", "time": 1605244567}, {"author_name": "JANE LIU", "author_url": "https://www.google.com/maps/contrib/118408366000315962541/reviews", "language": "zh-Hant", "profile_photo_url": "https://lh3.googleusercontent.com/a-/AOh14GhLwTvXxHtkjSMnFbuXthSgJSFkTtJ2Ce6dZBCUE6k=s128-c0x00000000-cc-rp-mo-ba5", "rating": 5, "relative_time_description": "1 個月前", "text": "》樂福利《-第一道菜是手工炸饅頭 藍紋乳酪外面炸得酥脆，讓我想到炸甜甜圈的感覺，裡面是藍紋起司，鹹香美味，要小心被那宛如熾熱岩漿的起司燙到！-開胃菜：長得很像馬卡龍，但我忘記這是什麼啦～印象中裡面有九層塔醬，上面有蒔蘿，放在小石頭上，覺得特別有趣！-黃花閨秀送秋波 綠意盎然水上飄：其實就是鹽酥雞，然後搭配上白胡椒跟九層塔做成的醬汁，雞肉是使用吃紅茶茶葉的珍珠雞，十分軟嫩多汁。-鴨肝蒸蛋 蟹肉玉米羹：把鴨肝跟蛋打在一起，然後裡面放了蟹肉、玉米、海葡萄、蓮子等食材，覺得這道充滿著海味的鮮甜，所有的精華都融化在蛋裡面！-酒釀乾燒鮑 銀牙百合：這個是使用整顆南非鮑魚，燉煮了整整6小時，在鮑魚仍有知覺時開始起算，那個乾燒醬佐蒜末搭配整顆軟嫩的鮑魚真的好厲害，好好食！-中場休息趣味小點：我被他燙到了XD只覺得超燙，外面是酥皮，覺得有那麼小的酥皮真的很可愛，通常都是看到玉米濃湯上的大酥皮！-經典雙醬肋眼牛排：靈感來自於夜市的鐵板牛排，雙醬就是我們熟悉的黑胡椒醬跟蘑菇醬佐蒜片，然後底下的鐵板麵用固態的方式呈現，上面放上節瓜跟蛋碎，覺得很有趣，夜市牛排的精髓都這樣巧妙的呈現在這道料理中，牛肉很嫩，沒有什麼筋，這道可謂中西合璧！另一道主餐-咦？這是薑母鴨！就是用鴨胸做成的，我吃了一口算是軟嫩，旁邊還有用豆腐跟米酒燉煮的蘿蔔。-甜點喔阿憨吉 芋頭與地瓜：真的很好吃，不會很甜膩，上面那片餅乾很像爆米香，底下有芋頭塊，灑上花生粉，感覺這碗許多台灣有特色的小點心影子。-茶莊精選茶跟配茶小點心：還有一大盤甜點，瑪德蓮、乳酪、堅果等⋯，真的好飽！菜單大約3個月就會換一次，這次我覺得他們靈感來源源自於台灣特色美食，像是夜市牛排、薑母鴨、鹹酥雞、跟甜點⋯等，用法式的方式品台味，吃完覺得被一場色「鄉」味的饗宴給洗禮了！雖然價位稍高，一開始看菜單以為價格是年份⋯XD服務上，我覺得很棒，服務人員都會親切的跟我們介紹每道菜，水沒了馬上添水，快到我覺得備感尊榮阿，每一次使用的餐具都會收走，每次使用乾淨的餐具，讓我們可以吃到每一道菜的純粹，魔鬼藏在細節裡!", "time": 1604162790}, {"author_name": "Chang Fanny", "author_url": "https://www.google.com/maps/contrib/106414233209807566204/reviews", "language": "zh-Hant", "profile_photo_url": "https://lh3.googleusercontent.com/a-/AOh14GhEvWIpMMrmwFwAPyIB2J0yeB96RIu4o1daIaOMmg=s128-c0x00000000-cc-rp-mo-ba4", "rating": 4, "relative_time_description": "1 個月前", "text": "預約午餐時間，從十二點吃到三點多，總共點五份不便宜的雙人套餐。其中等待的時間居多，推薦給有話聊的朋友來吃，如果只是想吃飽、不想花太多時間用餐的朋友就別來了。P.S偏重口味，喜歡清淡口味的朋友請PASS", "time": 1604821900}, {"author_name": "annie", "author_url": "https://www.google.com/maps/contrib/100305387888695354589/reviews", "language": "zh-Hant", "profile_photo_url": "https://lh3.googleusercontent.com/a-/AOh14GjVCmUDPwoMbL-iqWEIyNrf80X0gm6TQvpY_gLJlA=s128-c0x00000000-cc-rp-mo", "rating": 5, "relative_time_description": "1 個月前", "text": ""富含創意的台式西餐，料理中皆融入台灣元素，環境優雅，工作人員給人的感覺也很舒服。"", "time": 1603850803}, {"author_name": "吳蕙仲", "author_url": "https://www.google.com/maps/contrib/114941439035098000115/reviews", "language": "zh-Hant", "profile_photo_url": "https://lh6.googleusercontent.com/-VxmodlZh_G0/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucluEMuJvA_-sHnUJfd1r7Z8FL2KMw/s128-c0x00000000-cc-rp-mo/photo.jpg", "rating": 5, "relative_time_description": "2 個月前", "text": "2020.10.16為友人安排慶生，從去電訂位時就可以感受到服務的專業與貼心。當天用餐氛圍感覺很放鬆自在，餐點美味搭配得宜，服務用心細膩體貼，是間有溫度的高級法式餐廳。", "time": 1602990314}]'

# %%
df.iloc[714,:]
# Out:
# name                              樂福利餐酒館 Casual Dinning Room
# rating                                                   4.4
# address                                         桃園市桃園區永順街21號
# price                                                   2300
# lat                                                  25.0067
# lng                                                  121.295
# review     [{'author_name': 'Sky Cho', 'author_url': 'htt...
# image_0    https://no37elephant.github.io/default_image/r...
# image_1    https://no37elephant.github.io/default_image/s...
# image_2    https://no37elephant.github.io/default_image/m...
# image_3    https://no37elephant.github.io/default_image/l...
# image_4    https://no37elephant.github.io/default_image/l...
# Name: 729, dtype: object

# %%
cur.execute(f'''select * from bar where address = '桃園市桃園區永順街21號' ''')
data = cur.fetchall()
record = (data[0][0], data[0][1], data[0][2], data[0][3], data[0][4],
        data[0][5], data[0][6], data[0][7], string, data[0][9])

table_columns = '(name, rating, address, avg_price, url, tel, lat, lng, review, place_id)'
postgres_insert_query = f'''insert into bar {table_columns} 
values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
cur.execute(f"delete from bar where address = '桃園市桃園區永順街21號'")

cur.execute(postgres_insert_query, record)
cur.execute(f"select review from bar where address = '桃園市桃園區永順街21號'")
review=cur.fetchall()
convert_review_to_json(review[0][0])
# Out:
# ({'author_name': 'Sky Cho',
#   'author_url': 'https://www.google.com/maps/contrib/106032870450419582965/reviews',
#   'language': 'zh-Hant',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/-UPkijgiNjl8/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclet6gomd5BxkX6bWhyvYaz7jalew/s128-c0x00000000-cc-rp-mo/photo.jpg',
#   'rating': 3,
#   'relative_time_description': '1 個月前',
#   'text': '覺得以前的菜色比較好吃從南部到北部玩每次都會想來這！這是第二次來訪餐廳～但有點小失望...我來之前有訂狗狗餐從小份450$變1000$我是覺得無所謂...但是1000$的餐點是美國牛一開始覺得份量1000$應該是多的或更美味...但是1000$蔬菜一點點、肉肉一點點...沒有任何東西...感覺比我們的前菜不如也不如主菜...瞬間覺得之前450$她吃的比較開心...覺得帶她去吃高級和牛比較划算～餐點部份前菜還ok主菜真的有點太鹹了！畢竟我們不是外國人調味不會吃太重好可惜～我是個喜歡帶狗狗品嚐高級料理的人這次真的失望～難得有這樣的餐廳希望你們可以更好～～～～所以只給3星這樣會覺得不如去 L’ATELIER Joël Robuchon的味道和價位比較符合期望！這樣才符合vp 質～',
#   'time': 1605244567},
#  {'author_name': 'JANE LIU',
#   'author_url': 'https://www.google.com/maps/contrib/118408366000315962541/reviews',
#   'language': 'zh-Hant',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14GhLwTvXxHtkjSMnFbuXthSgJSFkTtJ2Ce6dZBCUE6k=s128-c0x00000000-cc-rp-mo-ba5',
#   'rating': 5,
#   'relative_time_description': '1 個月前',
#   'text': '》樂福利《-第一道菜是手工炸饅頭 藍紋乳酪外面炸得酥脆，讓我想到炸甜甜圈的感覺，裡面是藍紋起司，鹹香美味，要小心被那宛如熾熱岩漿的起司燙到！-開胃菜：長得很像馬卡龍，但我忘記這是什麼啦～印象中裡面有九層塔醬，上面有蒔蘿，放在小石頭上，覺得特別有趣！-黃花閨秀送秋波 綠意盎然水上飄：其實就是鹽酥雞，然後搭配上白胡椒跟九層塔做成的醬汁，雞肉是使用吃紅茶茶葉的珍珠雞，十分軟嫩多汁。-鴨肝蒸蛋 蟹肉玉米羹：把鴨肝跟蛋打在一起，然後裡面放了蟹肉、玉米、海葡萄、蓮子等食材，覺得這道充滿著海味的鮮甜，所有的精華都融化在蛋裡面！-酒釀乾燒鮑 銀牙百合：這個是使用整顆南非鮑魚，燉煮了整整6小時，在鮑魚仍有知覺時開始起算，那個乾燒醬佐蒜末搭配整顆軟嫩的鮑魚真的好厲害，好好食！-中場休息趣味小點：我被他燙到了XD只覺得超燙，外面是酥皮，覺得有那麼小的酥皮真的很可愛，通常都是看到玉米濃湯上的大酥皮！-經典雙醬肋眼牛排：靈感來自於夜市的鐵板牛排，雙醬就是我們熟悉的黑胡椒醬跟蘑菇醬佐蒜片，然後底下的鐵板麵用固態的方式呈現，上面放上節瓜跟蛋碎，覺得很有趣，夜市牛排的精髓都這樣巧妙的呈現在這道料理中，牛肉很嫩，沒有什麼筋，這道可謂中西合璧！另一道主餐-咦？這是薑母鴨！就是用鴨胸做成的，我吃了一口算是軟嫩，旁邊還有用豆腐跟米酒燉煮的蘿蔔。-甜點喔阿憨吉 芋頭與地瓜：真的很好吃，不會很甜膩，上面那片餅乾很像爆米香，底下有芋頭塊，灑上花生粉，感覺這碗許多台灣有特色的小點心影子。-茶莊精選茶跟配茶小點心：還有一大盤甜點，瑪德蓮、乳酪、堅果等⋯，真的好飽！菜單大約3個月就會換一次，這次我覺得他們靈感來源源自於台灣特色美食，像是夜市牛排、薑母鴨、鹹酥雞、跟甜點⋯等，用法式的方式品台味，吃完覺得被一場色「鄉」味的饗宴給洗禮了！雖然價位稍高，一開始看菜單以為價格是年份⋯XD服務上，我覺得很棒，服務人員都會親切的跟我們介紹每道菜，水沒了馬上添水，快到我覺得備感尊榮阿，每一次使用的餐具都會收走，每次使用乾淨的餐具，讓我們可以吃到每一道菜的純粹，魔鬼藏在細節裡!',
#   'time': 1604162790},
#  {'author_name': 'Chang Fanny',
#   'author_url': 'https://www.google.com/maps/contrib/106414233209807566204/reviews',
#   'language': 'zh-Hant',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14GhEvWIpMMrmwFwAPyIB2J0yeB96RIu4o1daIaOMmg=s128-c0x00000000-cc-rp-mo-ba4',
#   'rating': 4,
#   'relative_time_description': '1 個月前',
#   'text': '預約午餐時間，從十二點吃到三點多，總共點五份不便宜的雙人套餐。其中等待的時間居多，推薦給有話聊的朋友來吃，如果只是想吃飽、不想花太多時間用餐的朋友就別來了。P.S偏重口味，喜歡清淡口味的朋友請PASS',
#   'time': 1604821900},
#  {'author_name': 'annie',
#   'author_url': 'https://www.google.com/maps/contrib/100305387888695354589/reviews',
#   'language': 'zh-Hant',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14GjVCmUDPwoMbL-iqWEIyNrf80X0gm6TQvpY_gLJlA=s128-c0x00000000-cc-rp-mo',
#   'rating': 5,
#   'relative_time_description': '1 個月前',
#   'text': '富含創意的台式西餐，料理中皆融入台灣元素，環境優雅，工作人員給人的感覺也很舒服。',
#   'time': 1603850803},
#  {'author_name': '吳蕙仲',
#   'author_url': 'https://www.google.com/maps/contrib/114941439035098000115/reviews',
#   'language': 'zh-Hant',
#   'profile_photo_url': 'https://lh6.googleusercontent.com/-VxmodlZh_G0/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucluEMuJvA_-sHnUJfd1r7Z8FL2KMw/s128-c0x00000000-cc-rp-mo/photo.jpg',
#   'rating': 5,
#   'relative_time_description': '2 個月前',
#   'text': '2020.10.16為友人安排慶生，從去電訂位時就可以感受到服務的專業與貼心。當天用餐氛圍感覺很放鬆自在，餐點美味搭配得宜，服務用心細膩體貼，是間有溫度的高級法式餐廳。',
#   'time': 1602990314})

# %%
contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_shortest['image_0'].iloc[0]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": "Brown's T-shirts",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[0]},{df_shortest['lng'].iloc[0]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_shortest.index[0]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.1",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334b",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },
  {
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_shortest['image_0'].iloc[1]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": "Brown's T-shirts",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[1]},{df_shortest['lng'].iloc[1]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_shortest.index[1]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.2",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334b",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_shortest['image_0'].iloc[2]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": "Brown's T-shirts",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[2]},{df_shortest['lng'].iloc[2]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_shortest.index[2]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.3",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334b",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_shortest['image_0'].iloc[3]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": "Brown's T-shirts",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[3]},{df_shortest['lng'].iloc[3]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_shortest.index[3]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.4",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334b",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    },{
      "type": "bubble",
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "image",
            "url": f"{df_shortest['image_0'].iloc[4]}",
            "size": "full",
            "aspectMode": "cover",
            "aspectRatio": "2:3",
            "gravity": "top"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "text",
                    "text": "Brown's T-shirts",
                    "size": "xl",
                    "color": "#ffffff",
                    "weight": "bold"
                  }
                ]
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "這樣去",
                        "color": "#ffffff",
                        "flex": 0,
                        "offsetTop": "-2px"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "borderWidth": "1px",
                "cornerRadius": "4px",
                "spacing": "sm",
                "borderColor": "#ffffff",
                "margin": "xl",
                "height": "40px",
                "action": {
                  "type": "uri",
                  "label": "action",
                  "uri": f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[4]},{df_shortest['lng'].iloc[4]}"
                }
              },
              {
                "type": "box",
                "layout": "vertical",
                "contents": [
                  {
                    "type": "filler"
                  },
                  {
                    "type": "box",
                    "layout": "baseline",
                    "contents": [
                      {
                        "type": "filler"
                      },
                      {
                        "type": "text",
                        "text": "別人怎麼說",
                        "offsetTop": "0px",
                        "color": "#ffffff",
                        "size": "md",
                        "flex": 0,
                        "align": "center"
                      },
                      {
                        "type": "filler"
                      }
                    ],
                    "spacing": "sm"
                  },
                  {
                    "type": "filler"
                  }
                ],
                "height": "40px",
                "cornerRadius": "4px",
                "borderWidth": "1px",
                "borderColor": "#ffffff",
                "margin": "lg",
                "action": {
                  "type": "postback",
                  "label": "action",
                  "data": f'{df_shortest.index[4]}'
                }
              }
            ],
            "position": "absolute",
            "offsetBottom": "0px",
            "offsetStart": "0px",
            "offsetEnd": "0px",
            "backgroundColor": "#03303Acc",
            "paddingAll": "20px",
            "paddingTop": "18px"
          },
          {
            "type": "box",
            "layout": "vertical",
            "contents": [
              {
                "type": "text",
                "text": "No.5",
                "color": "#ffffff",
                "align": "center",
                "size": "xs",
                "offsetTop": "3px"
              }
            ],
            "position": "absolute",
            "cornerRadius": "20px",
            "offsetTop": "18px",
            "backgroundColor": "#ff334b",
            "offsetStart": "18px",
            "height": "25px",
            "width": "53px"
          }
        ],
        "paddingAll": "0px"
      }
    }]
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1054-5d91c403f49c> in <module>
#      10           {
#      11             "type": "image",
# ---> 12             "url": f"{df_shortest['image_0'].iloc[0]}",
#      13             "size": "full",
#      14             "aspectMode": "cover",
#
# TypeError: 'NoneType' object is not subscriptable

# %%
line_bot_api.reply_message(
            event.reply_token,
            TemplateSendMessage(
            alt_text='Carousel Template',
            template=CarouselTemplate(
                columns=[
                    CarouselColumn(
                        thumbnail_image_url=df_shortest['image_0'].iloc[0],
                        title=df_shortest['name'].iloc[0], text=' 124',
                        actions=[
                            URIAction(
                                label='這樣去',
                                uri=f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[0]},{df_shortest['lng'].iloc[0]}"
                            ),
                            PostbackAction(
                                label = '聽聽別人怎麼說',
                                data = f'{df_shortest.index[0]}'
                        )]),
                    CarouselColumn(
                        thumbnail_image_url=df_shortest['image_0'].iloc[1],
                        title=df_shortest['name'].iloc[1], text=' ',
                        actions=[
                            URIAction(
                                label='這樣去',
                                uri=f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[1]},{df_shortest['lng'].iloc[1]}"
                            ),
                            PostbackAction(
                                label = '聽聽別人怎麼說',
                                data = f'{df_shortest.index[1]}'
                        )]),
                    CarouselColumn(
                        thumbnail_image_url=df_shortest['image_0'].iloc[2],
                        title=df_shortest['name'].iloc[2], text=' ',
                        actions=[
                            URIAction(
                                label='這樣去',
                                uri=f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[2]},{df_shortest['lng'].iloc[2]}"
                            ),
                            PostbackAction(
                                label = '聽聽別人怎麼說',
                                data = f'{df_shortest.index[2]}'
                        )]),
                    CarouselColumn(
                        thumbnail_image_url=df_shortest['image_0'].iloc[3],
                        title=df_shortest['name'].iloc[3], text=' ',
                        actions=[
                            URIAction(
                                label='這樣去',
                                uri=f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[3]},{df_shortest['lng'].iloc[3]}"
                            ),
                            PostbackAction(
                                label = '聽聽別人怎麼說',
                                data = f'{df_shortest.index[3]}'
                        )]),
                    CarouselColumn(
                        thumbnail_image_url=df_shortest['image_0'].iloc[4],
                        title=df_shortest['name'].iloc[4], text=' ',
                        actions=[
                            URIAction(
                                label='這樣去',
                                uri=f"https://www.google.com/maps/search/?api=1&query={df_shortest['lat'].iloc[4]},{df_shortest['lng'].iloc[4]}"
                            ),
                            PostbackAction(
                                label = '聽聽別人怎麼說',
                                data = f'{df_shortest.index[4]}'
                        )])

                ])))
